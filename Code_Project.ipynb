# %%
# !python --version
# Out:
# Python 3.11.11

# %%
# !nvidia-smi
# Out:
# Mon Feb 24 17:03:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# เส้นทางไปยังโฟลเดอร์ datasets
dataset_path = '/content/drive/MyDrive/Datasets'

# ตัวอย่างการใช้งาน เช่น อ่านไฟล์จากโฟลเดอร์ datasets
import os
print(os.listdir(dataset_path))  # แสดงรายการไฟล์ในโฟลเดอร์ datasets
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['labels', 'images']

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.5/112.6 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xkliUKSLndXQJOoa5WtC")
project = rf.workspace("sign2gether").project("sign2gether")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/Datasets/data.yaml' epochs=600 imgsz=640 plots=True patience=300

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Image(filename=f'/content/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train3/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train3/val_batch0_pred.jpg', width=600)
